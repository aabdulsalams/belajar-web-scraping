# %% [markdown]
# ### Inisialisasi Libary

# %%
from bs4 import BeautifulSoup
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# ### Pengecekan URL Target (Tersedia/Tidak)

# %%
def simple_get(url):
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None


def is_good_response(resp):
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)


def log_error(e):
    print(e)

# %%
def get_category_html(category):
    url = 'https://www.indonetwork.co.id/' + category + '/perusahaan?page=2'
    html_selenium = webdriver.Chrome('/Users/abdulsalam/Documents/dll/chromedriver')
    raw_html = simple_get(url)
    html_soup = BeautifulSoup(raw_html, 'html.parser')
    

    return html_soup

# %%
html = get_category_html('komputer-dan-laptop')
companies = html.find_all(class_='product-info')
for company in companies:
    company_name = company.find(class_='link_product').text.replace('\n',' ').replace('          ','').replace(' ','',1)
    if company.find('div', class_='rubymember') is not None:
        company_level = 'Premium Ruby'
    elif company.find('div', class_='blueonyxmember') is not None:
        company_level = 'Premium Blue Onyx'
    elif company.find('div', class_='goldmember') is not None:
        company_level = 'Premium Gold'
    else:
        company_level = 'Free'
    company_address = company.find(class_='seller-name').text.replace('\n',' ').replace('Alamat','').replace(':','').replace(' ','', 4).replace('&nbsp','')
    company_telephone = ''
    #company.find(class_='nowa').text.replace('\n',' \\ ')

    print(f'''
    Company Name\t: {company_name}
    Level\t\t: {company_level}
    Address\t\t: {company_address}
    Phone Number\t: {company_telephone}
    '''
    )
# Out:
#     Company Name	: Rabotti Indonesia
#     Level		: Premium Blue Onyx
#     Address		: Taman sari raya no 55aJakarta 11150
#     Phone Number	:
#
#
#     Company Name	: PT.SURRAMA TRIDAYA MANDIRI
#     Level		: Premium Blue Onyx
#     Address		: Citi Square Business Park Blok E No. 6 Jl. Peta Selatan RT 010 RW 001, Kalideres
#     Phone Number	:
#
#
#     Company Name	: PT. TRIKOMINDO KHARIS UTAMA ( Trikom Kharisma)
#     Level		: Premium Blue Onyx
#     Address		: Ruko Permata Ancol Blok G16. Jl. RE Martadinata. Kel. Pademangan Barat. Kec. Pademangan.
#     Phone Number	:
#
#
#     Company Name	: CV. DUTA MESH
#     Level		: Premium Blue Onyx
#     Address		: Office  Jln, Bhayangkara Raya No 10 ( Depan Kantor Puysdiklantas Polri )
#     Phone Number	:
#
#
#     Company Name	: TEKNIK MANDIRI
#     Level		: Premium Blue Onyx
#     Address		: Jl. Setia Warga 8 No.40 Rt 10/11 Grogol Petamburan, Jakarta Barat
#     Phone Number	:
#
#
#     Company Name	: Mega Teknindo
#     Level		: Premium Blue Onyx
#     Address		: LTC Lt. GF2 Blok A20 No.5-6, Jl. Hayam Wuruk No. 127
#     Phone Number	:
#
#
#     Company Name	: UD.BETHANYA
#     Level		: Premium Blue Onyx
#     Address		: Jalan KH. Hasyim Ashari No. 7
#     Phone Number	:
#
#
#     Company Name	: CV. JATIM TRONIK - Surabaya - Jawa Timur - Indonesia
#     Level		: Premium Blue Onyx
#     Address		: Jl. Raya Merak No.53 Rewwin Waru
#     Phone Number	:
#
#
#     Company Name	: ABP Mandiri
#     Level		: Premium Blue Onyx
#     Address		: Jl. Kol. Sugiono Ngingas Selatan No. 14B
#     Phone Number	:
#
#
#     Company Name	: PT. TANJUNG PERKASA
#     Level		: Premium Blue Onyx
#     Address		: Jl. Plumpang Raya no.9. Tg.Priok, Koja, Jak-Ut
#     Phone Number	:
#
#
#     Company Name	: AIRLANGGA TOKO
#     Level		: Premium Gold
#     Address		: Pertokoan Pasar Kenari Blok AKS Lt. 01 No. 75 / Jalan Salemba Raya
#     Phone Number	:
#
#
#     Company Name	: zeropromosi
#     Level		: Premium Gold
#     Address		: Jl. Arcadia Daan Mogot Blok H7 No.16,  Batuceper, Kec. Batuceper, Kota Tangerang, Banten 15122, Indonesia
#     Phone Number	:
#
#
#     Company Name	: PT TUNAS WIRAJAYA
#     Level		: Premium Gold
#     Address		: Jl. Tunas No. 117 Cimanggis - Depok, Jawa Barat 16952, Telp 021 87755866, Fax 021 87755866
#     Phone Number	:
#
#
#     Company Name	: PT.HIKMAH JAYA SENTOSA
#     Level		: Premium Gold
#     Address		: Jl Puskesmas No 36 kebagusan Pasar minggu jakarta selatan 12520 Indonesia
#     Phone Number	:
#
#
#     Company Name	: PT.HIKMAH JAYA SENTOSA (Agent And Stockist)
#     Level		: Premium Gold
#     Address		: JL. Puskesmas Nomor 36 Kebagusan Pasar MingguJakarta Selatan
#     Phone Number	:
#
#
#     Company Name	: PT. Total Abadi Solusindo ( Authorized Distributor & General Contractor )
#     Level		: Premium Gold
#     Address		: Jl.Dr.Krt Radjiman Widyodiningrat Ruko D'Arcade Blok A19Jatinegara Indah Central Bussiness Park, Pulo Jahe, Cakung , Jakarta Timur 13930
#     Phone Number	:
#
#
#     Company Name	: PT. ADI RAYA MANDIRI
#     Level		: Premium Gold
#     Address		: Jl.Pinang Raya No.70 Pondok Labu CilandakJakarta Selatan Indonesia
#     Phone Number	:
#
#
#     Company Name	: CV. ALDANA SEJAHTERA
#     Level		: Premium Gold
#     Address		: Ruko Kawasan Niaga Citra Grand Blok R7 No. 30 ; Jl. Raya Alternatif Cibubur Km.4, Cibubur 17435
#     Phone Number	:
#
#
#     Company Name	: CV. BINTANG PELANGI MAS
#     Level		: Premium Gold
#     Address		:   Koja Trademall Grand floor Blok QA6 No.7Jl. Kramat jaya No.30, Koja Jakarta Utara 15260
#     Phone Number	:
#
#
#     Company Name	: PT. Kreasi Mandiri Perkasa
#     Level		: Premium Gold
#     Address		: Jl. H. Iming No. 93 RT 003 RW 017 Beji - Depok 16421
#     Phone Number	:
#
#
#     Company Name	: CV. SAMUDERA TEKNIKINDO SELARAS
#     Level		: Premium Gold
#     Address		: Office  Jl. Tarum Barat 2, Ruko Pasar Bersih B-7 (Pintu 11) Kawasan Industri Jababeka II, Jayamukti, Cikarang, Bekasi - Jawa Barat
#     Phone Number	:
#
#
#     Company Name	: PT. DWI SUBUR MAKMUR
#     Level		: Premium Gold
#     Address		: Jl. Kayu Jati IV No. 25 Rawamangun
#     Phone Number	:
#
#
#     Company Name	: PT. ADI RAYA MANDIRI
#     Level		: Premium Gold
#     Address		: Jl. Pinang Raya No.70 Pondok Labu
#     Phone Number	:
#
#
#     Company Name	: Nael Computer
#     Level		: Premium Gold
#     Address		: Pusat Elektronik Harco Mangga Dua Plaza Lantai 2 Blok B No.132-133Kontak toko  021-62203489\whatssap       081317240187.Jln.Mangga Dua Raya-Jakarta
#     Phone Number	:
#
#
#     Company Name	: Karya Mandiri Instrument Indonesia
#     Level		: Premium Gold
#     Address		: Jl.Cilangkap Baru,Griya Amar Ma'Ruf No 2A,cilangkap-Cipayung Jakarta Timurr
#     Phone Number	:
#
#
#     Company Name	: cv lamtama sianturindo
#     Level		: Premium Gold
#     Address		: jln. raya cilincing no 20 , rt 015 / rw 016 . semper barat , cilincing jakarta utara
#     Phone Number	:
#
#
#     Company Name	: CV. Flindex Kreasindo Utama
#     Level		: Premium Gold
#     Address		: Jln. Pattimura, Ruko Segi 8 Blok A-815 Surabaya, Jawa Timur, Indonesia
#     Phone Number	:
#
#
#     Company Name	: PT ANDALAN BANGUN SEJAHTERA
#     Level		: Premium Gold
#     Address		: JL. Sumur Batu No.1 RT.01 - RW.06 Kel.Sumur Batu - Kec.. Kemayoran
#     Phone Number	:
#
#
#     Company Name	: BEFINDO SEJAHTERA ELECTRONICS
#     Level		: Premium Gold
#     Address		: Jl Latumenten 3 No.9 , Rt008 / Rw05
#     Phone Number	:
#
#
#     Company Name	: Metrix Inspira
#     Level		: Premium Gold
#     Address		: Jl. Cireundeu Raya No 57 Pisangan Ciputat Timur Tangerang selatan
#     Phone Number	:
